# %%
import pandas as pd
import selenium
import time

from selenium import webdriver

from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Que 1

# %%
driver = webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe') 
time.sleep(2)

url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

time.sleep(2)

name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
    for i in names:
        name.append(i.text)
except NoSuchElementException: 
    name.append('No details available')
    
time.sleep(2)   

rank=[]
try:
    ranks=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException: 
    rank.append('No details available')

time.sleep(2)

artist=[]
try:
    artists=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artists:
        artist.append(i.text)
except NoSuchElementException:  
    artist.append('No details available')
time.sleep(2)  

views=[]
try:
    views_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views_list:
        views.append(i.text)
except NoSuchElementException: 
    views.append('No details available')
    
time.sleep(2) 

upload_date=[]
try:
    upload_date_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date_list:
        upload_date.append(i.text)
except NoSuchElementException: 
    upload_date.append('No details available')
    time.sleep(2) 
    
df = pd.DataFrame({"Rank":rank,
                 "Name":name,
                "Uploader/artist":artist,
                "Date of upload":upload_date,
                "Views(in billion)":views})
df


driver.close()
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[22]
# 8    9.                                "Uptown Funk"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                          "Thinking Out Loud"[36]
# 18  19.                                     "Axel F"[37]
# 19  20.                             "Girls Like You"[38]
# 20  21.                                      "Faded"[39]
# 21  22.                                 "Dark Horse"[40]
# 22  23.                                 "Let Her Go"[41]
# 23  24.                        "Baa Baa Black Sheep"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                               "Shake It Off"[45]
# 27  28.                                    "Perfect"[46]
# 28  29.           "Waka Waka (This Time for Africa)"[47]
# 29  30.                                   "Mi Gente"[48]
#
#                                 Uploader/artist     Date of upload  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                    Luis Fonsi   January 12, 2017
# 2                                   LooLoo Kids    October 8, 2016
# 3                                    Ed Sheeran   January 30, 2017
# 4                                   Wiz Khalifa      April 6, 2015
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018
# 6                                     ChuChu TV      March 6, 2014
# 7                                   Miroshka TV  February 27, 2018
# 8                                   Mark Ronson  November 19, 2014
# 9                                    Get Movies   January 31, 2012
# 10                                          Psy      July 15, 2012
# 11                   Cocomelon – Nursery Rhymes       May 24, 2018
# 12                                    El Chombo      April 5, 2018
# 13                                     Maroon 5   January 14, 2015
# 14                                   Katy Perry  September 5, 2013
# 15                                  OneRepublic       May 31, 2013
# 16                                Justin Bieber   October 22, 2015
# 17                                   Ed Sheeran    October 7, 2014
# 18                                   Crazy Frog      June 16, 2009
# 19                                     Maroon 5       May 31, 2018
# 20                                  Alan Walker   December 3, 2015
# 21                                   Katy Perry  February 20, 2014
# 22                                    Passenger      July 25, 2012
# 23                   Cocomelon – Nursery Rhymes      June 25, 2018
# 24                             Enrique Iglesias     April 11, 2014
# 25                                  Major Lazer     March 22, 2015
# 26                                 Taylor Swift    August 18, 2014
# 27                                   Ed Sheeran   November 9, 2017
# 28                                      Shakira       June 4, 2010
# 29                                     J Balvin      June 29, 2017
#
#    Views(in billion)
# 0              10.53
# 1               7.82
# 2               6.31
# 3               5.69
# 4               5.48
# 5               5.27
# 6               4.58
# 7               4.56
# 8               4.54
# 9               4.49
# 10              4.40
# 11              3.96
# 12              3.92
# 13              3.68
# 14              3.56
# 15              3.56
# 16              3.54
# 17              3.44
# 18              3.32
# 19              3.28
# 20              3.27
# 21              3.26
# 22              3.21
# 23              3.21
# 24              3.19
# 25              3.19
# 26              3.16
# 27              3.14
# 28              3.12
# 29              3.07

# %% [markdown]
# # Que 2

# %%
driver = webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe') 
time.sleep(2)

url = "https://www.bcci.tv/"
driver.get(url)


time.sleep(2)

int_tab =driver.find_element_by_xpath('//li[@class="nav-item ml-0"]').click()

# %%
# creating empty lists
Match_Title=[]
Series =[]
Place=[]
Date = []
Time=[]

# extracting title
titles=driver.find_elements_by_xpath('//span[@class="matchOrderText ng-binding ng-scope"]')

# extracting series
series =driver.find_elements_by_xpath('//span[@class="ng-binding"]')

#extarcting places
places=driver.find_elements_by_xpath('//div[@class="fix-place ng-binding ng-scope"]')

# extracting date 
dates=driver.find_elements_by_xpath('//div[@class="match-card-left match-schedule"]')

# extracting time
times=driver.find_elements_by_xpath('//div[@class="match-card-right match-schedule "]')

for i in range(len(titles)):
    title=titles[i].text     
    Match_Title.append(title)
    
    place=places[i].text     
    Place.append(place)
    
    serie=series[i].text     
    Series.append(serie)
    
    time=times[i].text     
    Time.append(time)
    
    date=dates[i].text     
    Date.append(date)



# Make dataframe
India_details_df = pd.DataFrame({'Match_Title':Match_Title,'Series':Series,'Place':Place,'Date':Date,'Time':Time})
India_details_df


driver.close()
# Out:
#   Match_Title                                      Series  \
# 0  1st T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 1  2nd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 2  3rd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 3  4th T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 4  5th T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
#
#                                                Place         Date         Time
# 0             1st T20I - Arun Jaitley Stadium, Delhi   9 JUN 2022  7:30 PM IST
# 1               2nd T20I - Barabati Stadium, Cuttack  12 JUN 2022  7:30 PM IST
# 2  3rd T20I - Dr YS Rajasekhara Reddy ACA-VDCA Cr...  14 JUN 2022  7:30 PM IST
# 3  4th T20I - Saurashtra Cricket Association Stad...  17 JUN 2022  7:30 PM IST
# 4        5th T20I - M Chinnaswamy Stadium, Bengaluru  19 JUN 2022  7:30 PM IST

# %% [markdown]
# # Que 3

# %%
driver=webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe') 
time.sleep(2)

url = "https://www.guru99.com/"
driver.get(url)
time.sleep(2)


selenium_link=driver.find_element_by_xpath("//li[@id='menu-item-4622']/a")
try:
    selenium_link.click()
except:          
    driver.get(selenium_link.get_attribute('href'))
time.sleep(2)

exception_handle_link=driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    exception_handle_link.click()
except ElementNotInteractableException:      
    driver.get(exception_handle_link.get_attribute('href'))              
time.sleep(2)    
    
name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
    for i in names[1:]:
        name.append(i.text)
except NoSuchElementException:               
    name.append('No details available')
time.sleep(2)   

desc=[]
try:
    desc_list=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
    for i in desc_list[1:]:
        desc.append(i.text)
except NoSuchElementException:
    desc.append('No details available')
time.sleep(2)

df=pd.DataFrame({"Exception_name":name,
                "Description":desc})
df

driver.close()
# Out:
#                          Exception_name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                                           Description
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# # Que 5

# %%
driver = webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe') 
time.sleep(2)

url = 'https://github.com/' #getting the required url
driver.get(url)

time.sleep(2)

# Getting explore button and clicking on it
explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()

#Selecting trending option
trend_url = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

#Creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

#Fetching urls for each repository
repository = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))

    
# Scraping Repository Title data
title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)

    
# Scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(3)
    
    
    # Scraping Repository Description data
    try:
        desc = driver.find_element_by_xpath("//p[@class='f4 mt-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        # Scraping Contributors Count data
    try:
        contributor = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
            
    # Scraping Languages used data
    try:
        for i in driver.find_elements_by_xpath("//span[@class='color-fg-default text-bold mr-1']"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
#creating dataframe
Github=pd.DataFrame({})
Github['Repository title'] = repository_title
Github['Repository description'] = Description
Github['Contributors count'] = Contributors
Github['Language used'] = Language
Github

driver.close()
# Out:
#                                      Repository title Repository description  \
# 0                          spacedriveapp / spacedrive                      -
# 1                                       ellie / atuin                      -
# 2                                      nuxt / nuxt.js                      -
# 3                                 mastodon / mastodon                      -
# 4                             PowerShell / PowerShell                      -
# 5                          521xueweihan / HelloGitHub                      -
# 6                                 Z4nzu / hackingtool                      -
# 7                      rochacbruno / python-week-2022                      -
# 8                                klauspost / compress                      -
# 9   labmlai / annotated_deep_learning_paper_implem...                      -
# 10                                Dec0ne / KrbRelayUp                      -
# 11                           why20021008 / hand-write                      -
# 12                     trustedsec / CS-Remote-OPs-BOF                      -
# 13                        Asabeneh / 30-Days-Of-React                      -
# 14                              mingrammer / diagrams                      -
# 15                    bregman-arie / devops-exercises                      -
# 16                                  hashcat / hashcat                      -
# 17                                    kedacore / keda                      -
# 18                  rmcelreath / stat_rethinking_2022                      -
# 19                          biggerduck / RedTeamNotes                      -
# 20                                        moby / moby                      -
# 21                                airbnb / javascript                      -
# 22                                       Vonng / ddia                      -
# 23                                     apache / flink                      -
# 24                                      spulec / moto                      -
#
#    Contributors count                                      Language used
# 0                  11  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 1                  29  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 2                 320  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 3                 665  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 4                 399  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 5                  11  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 6                  15  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 7                   5  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 8                  29  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 9                  12  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 10                  -  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 11                  -  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 12                  2  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 13                  8  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 14                104  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 15                 84  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 16                 94  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 17                195  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 18                  -  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 19                  -  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 20              2,162  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 21                481  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 22                 71  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 23              1,044  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...
# 24                783  [TypeScript, Rust, CSS, JavaScript, Swift, SCS...

# %% [markdown]
# # Que 6

# %%
driver=webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe') 
time.sleep(2)

url =  "https://www.billboard.com/charts/hot-100"
driver.get(url)

charts = driver.find_element_by_xpath("//a[@class='c-link  lrv-a-unstyle-link lrv-a-unstyle-link lrv-u-color-brand-accent-blue:hover lrv-a-hover-effect lrv-u-whitespace-nowrap lrv-u-color-grey-lightest ']")
charts.click()

hot = driver.find_element_by_xpath("//a[@class='c-label__link lrv-u-color-brand-primary u-color-black@mobile-max a-font-primary-bold lrv-u-font-size-32 u-whitespace-nowrap@tablet']")
hot.click()

ranks= driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // lrv-u-background-color-black lrv-u-color-white u-width-100 u-width-55@mobile-max u-width-55@tablet-only lrv-u-height-100p lrv-u-flex lrv-u-flex-direction-column@mobile-max lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey']")
rank=[]
for i in ranks:
    rank.append(i.text)

song=[]
firstsong = driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet']")
song.append(firstsong[0].text)

songs = driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
for i in songs:
    song.append(i.text)

artist=[]
firstartists = driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet']")
artist.append(firstartists[0].text)

artists = driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
for i in artists:
    artist.append(i.text)

lastweek=[]
peak_rank=[]
week=[]
lastweek_1= driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet']")


lastweek.append(lastweek_1[0].text)
peak_rank.append(lastweek_1[1].text)
week.append(lastweek_1[2].text)

lastweek_all= driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")

config=[]
for i in lastweek_all:
    config.append(i.text)

temp_lastweek=config[0::6]
for i in temp_lastweek:
    lastweek.append(i)

temp_peakrank=config[1::6]
for i in temp_peakrank:
    peak_rank.append(i)

temp_week=config[2::6]
for i in temp_week:
    week.append(i)

hot_100=pd.DataFrame()
hot_100['Rank']= rank
hot_100['Song Name']=song
hot_100['Artist Name']=artist
hot_100['Last Week Rank']=lastweek
hot_100['Peak Rank']=peak_rank
hot_100['Weeks On Board']=week
hot_100

driver.close()
# Out:
#    Rank     Song Name               Artist Name Last Week Rank Peak Rank  \
# 0     1     As It Was              Harry Styles              2         1
# 1     2   First Class               Jack Harlow              1         1
# 2     3    Heat Waves             Glass Animals              3         1
# 3     4    Big Energy                     Latto              4         3
# 4     5         Enemy     Imagine Dragons X JID              5         5
# ..  ...           ...                       ...            ...       ...
# 95   96       P Power     Gunna Featuring Drake             91        24
# 96   97  Money So Big                      Yeat              -        95
# 97   98  Blick Blick!   Coi Leray & Nicki Minaj             95        37
# 98   99  Fall In Love          Bailey Zimmerman              -        99
# 99  100  X Ultima Vez  Daddy Yankee & Bad Bunny             99        73
#
#    Weeks On Board
# 0               3
# 1               2
# 2              66
# 3              26
# 4              22
# ..            ...
# 95             14
# 96              4
# 97              4
# 98              1
# 99              3
#
# [100 rows x 6 columns]

# %% [markdown]
# # Que 7

# %%
driver=webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe') 
time.sleep(2)

# Opening the naukri.com
url = "https://www.naukri.com/browse-jobs"
driver.get(url)
time.sleep(2)
#Fetching urls to navigate recruiter page
recruiter = driver.find_element_by_xpath("/html/body/div[1]/div/ul/li[2]/a")
page_url = recruiter.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# Fetching search button, sending keys and clicking on it
search = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input") 
search.send_keys("Data Science ")           
btn = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button").click()     
time.sleep(3)
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


#Scraping data of Designation
for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)

#Scraping data of company name
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)
    
#scraping data of Skills 
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(3)
    #Scraping data of locations
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span"):
    Location.append(i.text)
time.sleep(3)

# Creating dataframe for scraped data
Naukri=pd.DataFrame({})
Naukri['Name'] = Name[:50]
Naukri['Designation'] = Designation[:50]
Naukri['Company'] = Company[:50]
Naukri['Skills'] = Skills[:50]
Naukri['Location'] = Location[:50]
Naukri

driver.close()
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                             Sandhya Khandagale
# 18                                    Ruchi Dhote
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                Dhruv Dev Dubey
# 31                                         Avodha
# 32                                      Jayanth N
# 33                                    Priya Khare
# 34                                       SREEDHAR
# 35                                     Ravi Dubey
# 36                                    Amit Sharma
# 37                                          Kanan
# 38                           Shashikant Chaudhary
# 39                                           Brad
# 40                                   Rutuja Pawar
# 41                            Madhusudhan Sridhar
# 42                                    Ankit Sinha
# 43                                 Gaurav Chouhan
# 44                                   Rashi Kacker
# 45                                        Ashwini
# 46                                   Balaji Kolli
# 47                                 Rajani Nagaraj
# 48                                    ROHIT Kumar
# 49                                 Amir Chowdhury
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                           HR Manager
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14                         HR Team Lead
# 15                 Assistant Manager HR
# 16                           HR Manager
# 17                         HR Recruiter
# 18  Senior Executive Talent Acquisition
# 19                         HR Executive
# 20           Manager Talent Acquisition
# 21                              HR Head
# 22                           HR MANAGER
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30             Company Recruitment Head
# 31       Business Development Associate
# 32                      Project Manager
# 33                       Senior Manager
# 34               Recruitment Consultant
# 35                  Recruitment Manager
# 36                           Consultant
# 37         senior technology instructor
# 38             HR Recruiter/HR Excutive
# 39        Manager, Technical Recruiting
# 40                  Technical Recruiter
# 41                      Erp Implementer
# 42                       Head Analytics
# 43              Chief Technical Officer
# 44                   Sr Product Manager
# 45             Director Global Delivery
# 46                           Co Founder
# 47                           HR Manager
# 48                            Architect
# 49                     Managing Partner
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   Infinitive Software Solutions
# 11                              Innominds Software
# 12                                        MoneyTap
# 13              QuantMagnum Technologies Pvt. Ltd.
# 14                               SocialPrachar.com
# 15                   BIZ INFOTECNO PRIVATE LIMITED
# 16                                  BISP Solutions
# 17                 Compumatrice Multimedia Pvt Ltd
# 18                           Bristlecone India Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                              Exela Technologies
# 25                 NEAL ANALYTICS SERVICES PVT LTD
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                                    Confidential
# 31                              Nikitha Palaparthi
# 32        Dollarbird Information Services Pvt, Ltd
# 33                          Independent Consultant
# 34     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
# 35                     HyrEzy Talent Solutions LLP
# 36                                 ASCO consulting
# 37                                         NY INST
# 38  3D India Staffing Research &amp; Consulting...
# 39                                     O.C. Tanner
# 40                                   Demand Matrix
# 41                             MADHUSUDHAN SRIDHAR
# 42                                  Suntech Global
# 43                        Strategic Consulting Lab
# 44                            Impel Labs Pvt. Ltd.
# 45                                    MRP Advisers
# 46                   Saras Solutions India Pvt Ltd
# 47                                     WildJasmine
# 48                             LNT Private Limited
# 49                                     Granular.ai
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Oracle Dba, Data Science, Data Warehousing, ET...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14  Social Media, digital media maketing, seo, smm...
# 15  React.js, Data Science, Java, Front End, Busin...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Big Data, Data Science, Artificial Intelligenc...
# 18  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Ethical Hacking, Security Operations Center, S...
# 32  Data Analytics, Managed Services, Team Leading...
# 33  Data Science, Artificial Intelligence, analyti...
# 34  Data Science, Machine Learning, Big Data Analy...
# 35  Walmart Interra Skeps Expressstores indifi whi...
# 36  Machine Learning, Artificial Intelligence, Dat...
# 37  C, C++, Artificial Intelligence, Python, Php, ...
# 38  Relationship Management, Retail Sales, Private...
# 39                 Data Science, Software Engineering
# 40  Data Science, Big Data Analytics, Digital Mark...
# 41                  Data Science, Recruitment, Salary
# 42  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 43  Software Development, Business Intelligence, B...
# 44                   Data Science, Node.js, Angularjs
# 45  Data Science, Media Marketing, Resource Planni...
# 46  Data Analysis, Learning, Data Science, Compute...
# 47  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 48  Software Development, Core Java, Unit Testing,...
# 49  Machine Learning, Data Science, Product Manage...
#
#                                          Location
# 0                                    Aakash Harit
# 1                                      HR Manager
# 2                                           Delhi
# 3                            shravan Kumar Gaddam
# 4                               Company Recruiter
# 5                        Hyderabad / Secunderabad
# 6                        MARSIAN Technologies LLP
# 7                                      Company HR
# 8                                            Pune
# 9                                    Anik Agrawal
# 10                              Company Recruiter
# 11                                      Ahmedabad
# 12                                   subhas patel
# 13                                    Founder CEO
# 14                                  UK - (london)
# 15   Abhishek - Only Analytics Hiring - India and
# 16                    Recruitment Lead Consultant
# 17                              Vadodara / Baroda
# 18  Institute for Financial Management and Resear
# 19                              Programme Manager
# 20                                        Chennai
# 21                                    Balu Ramesh
# 22                               HR Administrator
# 23                                     Trivandrum
# 24                                  Asif Lucknowi
# 25                                       Director
# 26                                         Indore
# 27                                InstaFinancials
# 28                                 Human Resource
# 29                          Bengaluru / Bangalore
# 30                                 Priyanka Akiri
# 31                                     HR Manager
# 32                                      Hyderabad
# 33                                Kalpana Dumpala
# 34                               Executive Hiring
# 35                       Hyderabad / Secunderabad
# 36                                        Mubarak
# 37                                     Company HR
# 38                          Bengaluru / Bangalore
# 39                                 Kushal Rastogi
# 40                                     Company HR
# 41                                         Mumbai
# 42                             Mahesh Babu Channa
# 43                                   HR Team Lead
# 44                       Hyderabad / Secunderabad
# 45                                Sakshi Chhikara
# 46                           Assistant Manager HR
# 47                                     Chandigarh
# 48                                   Kapil Devang
# 49                                     HR Manager

# %% [markdown]
# # Que 8

# %%
driver = webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe')
time.sleep(2)

# Getting required url
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)
time.sleep(2)

# Creating empty lists
Book_name =[]
Author_name = []
Volumes_sold= []
Publisher = []
Genre = []

# Scraping book name details
for i in driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]"):
    Book_name.append(i.text)

# Scraping author name details
for i in driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]"):
    Author_name.append(i.text)

# Scraping Volumes sold details
for i in driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]"):
    Volumes_sold.append(i.text)

# Scraping Publisher details
for i in driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]"):
    Publisher.append(i.text)

# Scraping Genre details
for i in driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]"):
    Genre.append(i.text)

# Creating dataframe to store the fethched data
Novels = pd.DataFrame({'Book_name':Book_name,'Author_name':Author_name,'Volumes_sold':Volumes_sold,'Publisher':Publisher,'Genre':Genre})
Novels

driver.close()
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # Que 9

# %%
driver = webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe')
time.sleep(2)

# Getting required url
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)

# Creating empty lists
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# Scraping name of the movie
for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

# Scrpaing Year span 
for i in driver.find_elements_by_xpath("//span[@class='lister-item-index unbold text-primary']"):
    Year_span.append(i.text)
    
# Scrpaing Genre 
for i in driver.find_elements_by_xpath("//span[@class='genre']"):
    Genre.append(i.text)
    
# Scrpaing Run_time 
for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
    Run_time.append(i.text)
    
# Scrpaing Ratings 
for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]"):
    Ratings.append(i.text)
    
# Scrpaing Votes 
for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)
    
print(len(Name),len(Year_span),len(Genre),len(Run_time),len(Ratings),len(Votes))

Tv_series = pd.DataFrame({'Name':Name,'Year_span':Year_span,'Genre':Genre,'Run_time':Run_time,'Ratings':Ratings,'Votes':Votes})
Tv_series

driver.close()
# Out:
# 100 100 100 100 100 100
#                               Name Year_span                     Genre  \
# 0                  Game of Thrones        1.  Action, Adventure, Drama
# 1                  Stranger Things        2.    Drama, Fantasy, Horror
# 2                 The Walking Dead        3.   Drama, Horror, Thriller
# 3                   13 Reasons Why        4.  Drama, Mystery, Thriller
# 4                          The 100        5.    Drama, Mystery, Sci-Fi
# ..                             ...       ...                       ...
# 95                           Reign       96.            Drama, Fantasy
# 96  A Series of Unfortunate Events       97.  Adventure, Comedy, Drama
# 97                  Criminal Minds       98.     Crime, Drama, Mystery
# 98           Scream: The TV Series       99.      Comedy, Crime, Drama
# 99      The Haunting of Hill House      100.    Drama, Horror, Mystery
#
#    Run_time Ratings      Votes
# 0    57 min     9.2  1,978,820
# 1    51 min     8.7    984,481
# 2    44 min     8.2    943,200
# 3    60 min     7.5    281,785
# 4    43 min     7.6    241,741
# ..      ...     ...        ...
# 95   42 min     7.4     48,487
# 96   50 min     7.8     59,119
# 97   42 min     8.1    188,528
# 98   45 min     7.1     39,966
# 99  572 min     8.6    226,025
#
# [100 rows x 6 columns]

# %% [markdown]
# # Que 10

# %%
driver = webdriver.Chrome(r'C:\Users\dell\Downloads\chromedriver_win32\chromedriver.exe')
time.sleep(2)

# Getting required url
url = "https://archive.ics.uci.edu/ml/datasets.php"
driver.get(url)

#Creating empty lists for storing the data
Name=[]
Type=[]
Task=[]
Attribute=[]
No_of_Instance=[]
No_of_Attribute=[]
Year=[]

#Scrapping the data having dataset name
try:
    names=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
    
#Scrapping the data having data type
try:
    types=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in types[1:]:
        Type.append(i.text)
except NoSuchElementException:
    Type.append('-')
    
#Scrapping the data having default task
try:
    task=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in task[1:]:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('-')
        
#Scrapping the data having attribute types
try:
    attribute=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in attribute[1:]:
        Attribute.append(i.text)
except NoSuchElementException:
     Attribute.append('-')
        
#Scrapping the data having no of instances
try:
    instance=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in instance[1:]:
        No_of_Instance.append(i.text)
except NoSuchElementException:
    No_of_Instance.append('-')
        
#Scrapping the data having no of attributes
try:
    attribute_no=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in attribute_no[1:]:
        No_of_Attribute.append(i.text)
except NoSuchElementException:
    No_of_Attribute.append('-')
        
#Scrapping the data having the year details
try:
    year=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in year[1:]:
        Year.append(i.text)
except NoSuchElementException:
    Year.append('-')
    

#Creating the dataframe
df=pd.DataFrame({"Name":Name,"Data types":Type,"Default Task":Task,"Attribute types":Attribute, 
                 "No of instances":No_of_Instance,"No of atrributes":No_of_Attribute,"Year":Year})
df

driver.close()
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                      Data types          Default Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# 4                 Multivariate        Classification
# ..                          ...                   ...
# 617               Multivariate        Classification
# 618               Multivariate        Classification
# 619                                   Classification
# 620  Multivariate, Time-Series        Classification
# 621                 Univariate            Regression
#
#                  Attribute types No of instances No of atrributes   Year
# 0    Categorical, Integer, Real            4177                8   1995
# 1          Categorical, Integer           48842               14   1996
# 2    Categorical, Integer, Real             798               38
# 3                   Categorical           37711              294   1998
# 4    Categorical, Integer, Real             452              279   1998
# ..                           ...             ...              ...    ...
# 617               Integer, Real           75840              525   2020
# 618               Integer, Real             400               50   2020
# 619                                        1014                7   2020
# 620                        Real           10129               16   2021
# 621                        Real            4000                2   2021
#
# [622 rows x 7 columns]
